# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
import re

# %%
datasets=[]
object={}
target_url = "https://www.zillow.com/homes/for_sale/Brooklyn,-New-York,-NY_rb/"

headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36","Accept-Language":"en-US,en;q=0.9","Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9","Accept-Encoding":"gzip, deflate, br","upgrade-insecure-requests":"1"}

req = requests.get(target_url, headers=headers).text

for page in range(1,20):  ###change max page number here  
    req =  requests.get("https://www.zillow.com/homes/for_sale/Brooklyn,-New-York,-NY_rb/{}_p/".format(page), headers=headers).text
    soup = BeautifulSoup(req,'html.parser')

    properties = soup.find_all("div",{"class":"StyledPropertyCardDataWrapper-c11n-8-73-8__sc-1omp4c3-0 gXNuqr property-card-data"})
    print(len(properties))

    for x in range(0,len(properties)):
      try:
        object["pricing"]=properties[x].find("div",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 hRqIYX"}).text
      except:
        object["pricing"]=None
      try:
        object["size"]=properties[x].find("div",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 ghGYOB"}).text

      except:
        object["size"]=None
      try:
        object["address"]=properties[x].find("a",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 lhIXlm property-card-link"}).text
      except:
        object["address"]=None
      try:
        object["link"]=properties[x].find('a', {'href': re.compile("^https://")}).get('href')
      except:
        object["link"]=None
      datasets.append(object)
      object={}
print(datasets)
    
df = pd.DataFrame(datasets)
df
df.to_csv('zillow_datasets.csv')
# Out:
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# [{'pricing': '$1,179,000', 'size': '5 bds5 ba2,240 sqft - House for sale', 'address': '50 Barbey St, Brooklyn, NY 11207', 'link': 'https://www.zillow.com/homedetails/50-Barbey-St-Brooklyn-NY-11207/30636718_zpid/'}, {'pricing': '$110,000', 'size': 'Studio 1 ba2,400 sqft - Apartment for sale', 'address': '7416 20th Ave, Brooklyn, NY 11204', 'link': 'https://www.zillow.com/homedetails/7416-20th-Ave-Brooklyn-NY-11204/30705737_zpid/'}, {'pricing': '$275,000', 'size': '4 bds1 ba-- sqft - Condo for sale', 'address': '595 Franklin Ave APT 3R, Brooklyn, NY 11238', 'link': 'https://www.zillow.com/homedetails/595-Franklin-Ave-APT-3R-Brooklyn-NY-11238/245066787_zpid/'}, {'pricing': '$250,000', 'size': '6 bds3 ba2,630 sqft - Multi-family home for sale', 'address': '3017 Brighton 7 St #1-2, Brooklyn, NY 11235', 'link': 'https://www.zillow.com/homedetails/3017-Brighton-7-St-1-2-Brooklyn-NY-11235/2061726388_zpid/'}, {'pricing': '$650,000', 'size': '3 bds2 ba1,040 sqft - Condo for sale', 'address': '3814 Shore Pkwy #3C, Brooklyn, NY 11235', 'link': 'https://www.zillow.com/homedetails/3814-Shore-Pkwy-3C-Brooklyn-NY-11235/82770594_zpid/'}, {'pricing': '$579,900', 'size': '3 bds2 ba1,540 sqft - House for sale', 'address': '4310 Clarendon Rd, Brooklyn, NY 11203', 'link': 'https://www.zillow.com/homedetails/4310-Clarendon-